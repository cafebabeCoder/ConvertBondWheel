# %%
import baostock as bs
import pandas as pd

# %%
lg = bs.login()
# Out:
# login success!

# %%
rs = bs.query_history_k_data_plus("sz.127010",
    "date",
    start_date='2019-05-01', end_date='2019-06-05', 
    frequency="d", adjustflag="3") #frequency="d"取日k线，adjustflag="3"默认不复权
print('query_history_k_data_plus respond error_code:'+rs.error_code)
print('query_history_k_data_plus respond  error_msg:'+rs.error_msg)
# Out:
# query_history_k_data_plus respond error_code:0
# query_history_k_data_plus respond  error_msg:success

# %%
data_list = []
while (rs.error_code == '0') & rs.next():
    # 获取一条记录，将记录合并在一起
    data_list.append(rs.get_row_data())
result = pd.DataFrame(data_list, columns=rs.fields)

# %%
result
# Out:
# Empty DataFrame
# Columns: [date]
# Index: []

# %%
import tushare as ts

# %%
ts.set_token('047e2bcae2ea6c2f6f225eeb62087d27e1981988e758c82ba1997971')

# %%
pro = ts.pro_api()

# %%
df = pro.daily(ts_code='603912.SH', start_date=start_dt, end_date=end_dt)

# %%
df = pro.trade_cal(exchange='', start_date='20190601', end_date='20190605', fields='exchange,cal_date,is_open,pretrade_date', is_open='0')

# %%
data = pro.query('stock_basic', exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')

# %%
data.head()
# Out:
#      ts_code  symbol  name area industry list_date
# 0  000001.SZ  000001  平安银行   深圳       银行  19910403
# 1  000002.SZ  000002   万科A   深圳     全国地产  19910129
# 2  000004.SZ  000004  国农科技   深圳     生物制药  19910114
# 3  000005.SZ  000005  世纪星源   深圳     环境保护  19901210
# 4  000006.SZ  000006  深振业A   深圳     区域地产  19920427

# %%
data[data.ts_code=='127009.SH']
# Out:
# Empty DataFrame
# Columns: [ts_code, symbol, name, area, industry, list_date]
# Index: []

# %%
data[data.name.str.contains('债')]
# Out:
# Empty DataFrame
# Columns: [ts_code, symbol, name, area, industry, list_date]
# Index: []

# %%
print(ts.__version__)
# Out:
# 1.2.35

# %%
df = ts.new_cbonds(default=0)
# Out:
# #######

# %%
df
# Out:
#       bcode   bname   scode sname     xcode  amount  marketprice  convprice  \
# 0    113537    文灿转债  603348  文灿股份    754348    8.00          NaN      19.93
# 1    123026    中环转债  300692  中环环保    370692    2.90          NaN      12.31
# 2    128068    和而转债  002402   和而泰    072402    5.47          NaN       9.09
# 3    113536    三星转债  603578  三星新材    754578    1.92          NaN      19.75
# 4    113535    大业转债  603278  大业股份    754278    5.00       100.63      12.56
# 5    128067    一心转债  002727   一心堂    072727    6.03       106.15      27.28
# 6    128066    亚泰转债  002811  亚泰国际    072811    4.80        96.53      17.49
# 7    110058    永鼎转债  600105  永鼎股份    733105    9.80        94.02       6.50
# 8    128065    雅化转债  002497  雅化集团    072497    8.00        93.49       8.98
# 9    127013    创维转债  000810  创维数字    070810   10.40        96.63      11.56
# 10   113026    核能转债  601985  中国核电    783985   78.00       101.96       6.32
# ...

# %%
df.describe()
# Out:
#                bcode      amount  marketprice   convprice  firstdayprice  \
# count     308.000000  308.000000   301.000000  287.000000     282.000000
# mean   118960.792208   25.580162   126.488538   13.279129     108.659078
# std      8546.700044   52.732693    45.524804   11.878813      18.339708
# min    100001.000000    1.140000    91.010000    1.690000      68.750000
# 25%    110357.250000    5.752500    99.960000    6.150000      99.562500
# 50%    123005.500000   10.000000   106.700000    9.260000     106.450000
# 75%    127010.250000   21.132500   138.590000   15.880000     116.050000
# max    132015.000000  400.000000   366.000000   81.490000     229.000000
#
#          perreturn
# count   267.000000
# mean    324.926404
# std    1022.143294
# min       0.000000
# 25%      12.780000
# 50%      37.010000
# 75%     165.715000
# max    7856.420000

# %%
con=ts.get_apis()
dfs =  ts.bar('127009', conn=con)

# %%
dfs
# Out:
#               code     open    close     high      low     vol       amount  \
# datetime
# 2019-06-06  127009  133.990  130.199  134.150  129.601   329.0   43427128.0
# 2019-06-05  127009  137.000  132.000  137.647  131.000   323.0   43671884.0
# 2019-06-04  127009  132.000  133.899  136.750  129.010   568.0   76246440.0
# 2019-06-03  127009  145.690  131.800  146.299  131.200   554.0   76386232.0
# 2019-05-31  127009  146.000  145.000  146.886  144.010   496.0   72211672.0
# 2019-05-30  127009  144.000  145.677  147.800  142.690  1118.0  163171536.0
# 2019-05-29  127009  143.050  144.533  147.000  143.030   752.0  109166344.0
# 2019-05-28  127009  139.590  143.030  149.888  138.900  1928.0  279063840.0
# 2019-05-27  127009  136.500  139.039  140.370  136.500   796.0  110721368.0
# 2019-05-24  127009  133.500  135.900  139.000  133.500   863.0  117726472.0
# 2019-05-23  127009  134.499  133.999  137.200  133.020   344.0   46830832.0
# ...
