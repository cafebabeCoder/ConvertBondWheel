# %%
import pandas as pd
import matplotlib as mlp
import matplotlib.pyplot as plt

# %%
names=['value_score', 'bond_id', 'bond_nm', 'price', 'increase_rt', 'stock_nm', 'sprice',
                        'sincrease_rt',
                        'pb', 'convert_price', 'convert_value', 'premium_rt', 'rating_cd', 'put_convert_price',
                        'force_redeem_price', 'convert_amt_ratio', 'convert_dt', 'short_maturity_dt', 'year_left', 'ytm_rt',
                        'ytm_rt_tax', 'volume', 'vol_mean']

# %%
data=pd.read_csv("../../ConvertBondWheel/data/jisiluConvertBound_pre.csv", skiprows=1, names=names)

# %%
data.head()
# Out:
#    value_score  bond_id bond_nm    price increase_rt stock_nm  sprice  \
# 0      113.380   127019    国城转债  112.620      -0.34%     国城矿业   23.55
# 1      114.060   123004    铁汉转债  113.000      -2.16%     铁汉生态    4.45
# 2      116.380   113008    电气转债  110.360      -0.21%     上海电气    5.34
# 3      117.213   128013    洪涛转债  111.173      -0.34%     洪涛股份    3.25
# 4      117.352   128085    鸿达转债  111.902      -0.40%     鸿达兴业    4.16
#
#   sincrease_rt     pb  convert_price  ...  put_convert_price  \
# 0        0.43%  12.23          21.07  ...              14.75
# 1       -2.63%   1.70           3.98  ...               2.79
# 2       -0.37%   1.25           5.13  ...               3.59
# 3       -0.61%   1.28           3.10  ...               2.17
# 4       -1.89%   1.42           3.92  ...               2.74
#
#   force_redeem_price convert_amt_ratio  convert_dt  short_maturity_dt  \
# 0              27.39              3.2%  2021-01-21           26-07-14
# ...

# %%
pd.to_numeric(data['premium_rt'].str.replace("%", ""), downcast='float')
# Out:
# 0        0.760000
# 1        1.060000
# 2        6.020000
# 3        6.040000
# 4        5.450000
#           ...
# 292     51.939999
# 293    158.080002
# 294      0.970000
# 295    247.389999
# 296      1.580000
# Name: premium_rt, Length: 297, dtype: float32

# %%
data.describe()
# Out:
#        value_score        bond_id       price      sprice          pb  \
# count   297.000000     297.000000  297.000000  297.000000  297.000000
# mean    149.956471  120281.771044  131.587010   18.357879    3.327037
# std      67.050011    7166.739758   60.665866   20.728118    2.663383
# min     113.380000  110031.000000   80.406000    2.260000    0.470000
# 25%     126.550000  113535.000000  110.239000    7.330000    1.580000
# 50%     134.790000  123027.000000  118.570000   11.850000    2.550000
# 75%     148.160000  128041.000000  130.490000   21.730000    4.080000
# max     919.581000  128130.000000  918.001000  178.210000   19.340000
#
#        convert_price  convert_value  force_redeem_price   year_left  \
# count     297.000000     297.000000          297.000000  297.000000
# mean       15.467407     115.135926           20.078148    4.743896
# std        13.787865      60.424997           17.900958    1.088766
# ...

# %%
fig = plt.figure(figsize=(20, 20))
fig, ax = plt.subplots()
color = data['value_score'].astype(int)
area = (data['premium_rt'].str.replace("%", "").astype(float)).astype(int)
ax.scatter(data['increase_rt'].str.replace("%", ""), data['sincrease_rt'].str.replace("%", ""), c=color, s=area, alpha=0.5)
fig.tight_layout()
plt.show()

# %%
(100*data['premium_rt'].str.replace("%", "").astype(float)).astype(int)
# Out:
# 0         76
# 1        106
# 2        602
# 3        604
# 4        545
#        ...
# 292     5194
# 293    15808
# 294       97
# 295    24739
# 296      158
# Name: premium_rt, Length: 297, dtype: int64

# %%
color
# Out:
# 0      113
# 1      114
# 2      116
# 3      117
# 4      117
#       ...
# 292    346
# 293    446
# 294    505
# 295    598
# 296    919
# Name: value_score, Length: 297, dtype: int64
