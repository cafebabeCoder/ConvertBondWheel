# %%
import tushare as ts
import pandas as pd
ts.set_token('047e2bcae2ea6c2f6f225eeb62087d27e1981988e758c82ba1997971')

# %%
pro = ts.pro_api()


#获取可转债发行数据
df = pro.cb_issue(ts_code='110031.SH')


#获取可转债发行数据，自定义字段
# df = pro.cb_issue(fields='ts_code,ann_date,offl_deposit')
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/envs/scrapy_ts/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# ~/anaconda3/envs/scrapy_ts/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~/anaconda3/envs/scrapy_ts/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# timeout: timed out
#
# ...

# %%
df
# Out:
#      ts_code  ann_date res_ann_date plan_issue_size  issue_size  issue_price  \
# 0  110031.SH  20150610     20150617            None        24.0        100.0
#
#        issue_type onl_code onl_name  onl_date  ...  onl_pch_excess  \
# 0  优先配售,网上定价和网下配售   733271     航信发债  20150612  ...         3104.32
#
#    shd_ration_code  shd_ration_name  shd_ration_date shd_ration_record_date  \
# 0           704271             航信配债         20150612               20150611
#
#   shd_ration_pay_date shd_ration_price shd_ration_ratio shd_ration_size  \
# 0            20150612            100.0            2.599      19319730.0
#
#    offl_size
# 0  4595520.0
#
# [1 rows x 23 columns]

# %%
df[df.ann_date > '20200815']
# Out:
# Empty DataFrame
# Columns: [ts_code, ann_date, offl_deposit]
# Index: []

# %%
df1 = pro.cb_daily(ts_code='110031.SH', start_date='20200719')

# %%
df2 = pro.cb_daily(start_date='20200810')

# %%
df2.describe()
# Out:
#          pre_close        open         high          low        close  \
# count  1444.000000  1444.00000  1444.000000  1444.000000  1444.000000
# mean    137.887452   138.24876   142.604107   134.721558   138.110630
# std      68.855841    69.81405    74.940535    65.944933    68.884793
# min      79.420000     0.00000     0.000000     0.000000    79.420000
# 25%     112.680000   112.98750   114.322500   112.000000   113.000000
# 50%     122.500000   122.90000   125.000000   120.545000   122.215000
# 75%     140.720000   140.96750   145.530000   136.742500   139.755000
# max    1038.000000  1045.00000  1098.000000  1021.280000  1029.900000
#
#             change      pct_chg           vol         amount
# count  1444.000000  1444.000000  1.444000e+03    1444.000000
# mean      0.223179     0.193256  1.261264e+05   23009.941444
# std       8.469825     4.444283  3.286237e+05   65476.160706
# min     -62.900000   -16.800500  0.000000e+00       0.000000
# ...

# %%
pd.concat([df1, df2], axis=0)
# Out:
#       ts_code trade_date  pre_close    open    high     low   close  change  \
# 0   110031.SH   20200814     112.82  112.36  113.37  112.36  112.70   -0.12
# 1   110031.SH   20200813     112.42  112.78  112.99  112.53  112.82    0.40
# 2   110031.SH   20200812     112.69  112.80  113.17  112.30  112.42   -0.27
# 3   110031.SH   20200811     113.00  113.40  113.95  112.61  112.69   -0.31
# 4   110031.SH   20200810     112.49  112.99  114.12  112.70  113.00    0.51
# 5   110031.SH   20200807     112.70  112.61  112.96  111.98  112.49   -0.21
# 6   110031.SH   20200806     112.30  112.20  113.10  112.03  112.70    0.40
# 7   110031.SH   20200805     112.06  112.20  112.79  112.00  112.30    0.24
# 8   110031.SH   20200804     112.77  112.99  113.09  111.82  112.06   -0.71
# 9   110031.SH   20200803     113.00  113.50  114.51  112.66  112.77   -0.23
# 10  110031.SH   20200731     111.84  112.29  113.93  111.80  113.00    1.16
# ...

# %%
df.head()
# Out:
#      ts_code trade_date  pre_close    open    high     low   close  change  \
# 0  110031.SH   20200814     112.82  112.36  113.37  112.36  112.70   -0.12
# 1  110031.SH   20200813     112.42  112.78  112.99  112.53  112.82    0.40
# 2  110031.SH   20200812     112.69  112.80  113.17  112.30  112.42   -0.27
# 3  110031.SH   20200811     113.00  113.40  113.95  112.61  112.69   -0.31
# 4  110031.SH   20200810     112.49  112.99  114.12  112.70  113.00    0.51
#
#    pct_chg     vol    amount
# 0  -0.1064  1974.0  222.9056
# 1   0.3558  1690.0  190.4889
# 2  -0.2396  2832.0  319.3778
# 3  -0.2743  4268.0  484.2775
# 4   0.4534  2534.0  287.1339

# %%
df.describe()
# Out:
#         pre_close        open        high         low       close     change  \
# count   20.000000   20.000000   20.000000   20.000000   20.000000  20.000000
# mean   112.861000  113.256000  114.329000  112.270500  112.896000   0.035000
# std      0.870256    1.748637    1.723393    0.746863    0.847587   0.912114
# min    111.450000  111.980000  112.760000  111.100000  111.450000  -1.450000
# 25%    112.390000  112.342500  113.097500  111.842500  112.472500  -0.530000
# 50%    112.735000  112.790000  113.940000  112.165000  112.735000  -0.165000
# 75%    113.072500  113.425000  114.827500  112.550000  113.072500   0.427500
# max    115.010000  120.000000  120.000000  114.020000  115.010000   2.000000
#
#          pct_chg           vol       amount
# count  20.000000     20.000000    20.000000
# mean    0.034270  10204.300000  1161.645935
# std     0.809697  12481.216633  1445.392399
# min    -1.279900   1690.000000   190.488900
# 25%    -0.463925   3825.250000   432.232475
# ...

# %%
df.loc[:, 'vol'].mean()
# Out:
# 10204.3

# %%
from wxpy import *
bot = Bot()

# 机器人账号自身
myself = bot.self

# 向文件传输助手发送消息
bot.file_helper.send('Hello from wxpy!')
# Out:
# Getting uuid of QR code.
# ...
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-411c45df82f3> in <module>
#       1 from wxpy import *
# ----> 2 bot = Bot()
#       3
#       4 # 机器人账号自身
#       5 myself = bot.self
#
# ~/anaconda3/envs/scrapy_ts/lib/python3.7/site-packages/wxpy/api/bot.py in __init__(self, cache_path, console_qr, qr_path, qr_callback, login_callback, logout_callback)
#      84                 hotReload=bool(cache_path), statusStorageDir=cache_path,
#      85                 enableCmdQR=console_qr, picDir=qr_path, qrCallback=qr_callback,
# ---> 86                 loginCallback=login_callback, exitCallback=logout_callback
#      87             )
#      88         except FileNotFoundError as e:
#
# ...
